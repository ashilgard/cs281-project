# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set_context('poster')

# %%
ref_all = []
ref_scores = np.loadtxt('./ref/ref_scores_adult.csv')
for num_clust in [15, 75, 105]:
    ref_all.append(np.loadtxt('./ref/ref_all_clust_{}_adult.csv'.format(num_clust)))

# %%
for num_clust in [15, 75, 105]:
    print('./ref/ref_all_clust_{}_adult.csv'.format(num_clust))
# Out:
# ./ref/ref_all_clust_15_adult.csv
# ./ref/ref_all_clust_75_adult.csv
# ./ref/ref_all_clust_105_adult.csv

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(range(15,115,15), ref_scores[:,0], label='Delta Matrix Clustering')
plt.plot(range(15,115,15), clust_scores[:,0,0], c='r', label = 'Latent Variables, K=2')
plt.plot(range(15,115,15), clust_scores[:,2,0], c='g', label = 'Latent Variables, K=6')
plt.plot(range(15,115,15), clust_scores[:,4,0], c='y', label = 'Latent Variables, K=10')
plt.xlabel('Number of Clusters', fontsize=20)
plt.ylabel('Average Distance Between \n Cluster and Original Matrix', fontsize=20)
plt.legend(loc='upper right', prop={'size': 18})
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.title('Comparison of Latent Variable and \n Delta Matrix Clustering, Adult Dataset',  fontsize=30)
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.plot(range(15,115,15), ref_scores[:,0], label='Delta Matrix Clustering')
plt.plot(range(15,115,15), clust_scores[:,0,0], c='r', label = 'Latent Variables, K=2')
plt.plot(range(15,115,15), clust_scores[:,2,0], c='g', label = 'Latent Variables, K=6')
plt.plot(range(15,115,15), clust_scores[:,4,0], c='y', label = 'Latent Variables, K=10')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Distance Between \n Cluster and Original Matrix')
plt.legend(loc='upper right')
# plt.tick_params(axis='both', which='major', labelsize=16)
# plt.tick_params(axis='both', which='minor', labelsize=16)
plt.title('Comparison of Latent Variable and \n Delta Matrix Clustering, Adult Dataset')
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.hist(np.abs(clust_all[0]), alpha=.5, label='15 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[0]), alpha=.5 , label='15 Clusters, Matrix Clustering', bins=100)
# plt.hist(np.abs(clust_all[-1]), alpha=.5, label='105 Clusters, Latent Clustering, K=2', bins=100)
# plt.hist(np.abs(ref_all[-1]), alpha=.5 , label='105 Clusters, Matrix Clustering', bins=100)
plt.title('Distribution of Differences \n Adult Dataset',  fontsize=30)
plt.yscale('log', nonposy='clip')
plt.ylabel('Log Number of Occurences',  fontsize=20)
plt.xlabel('Difference',  fontsize=20)
plt.legend(loc='best', prop={'size': 18})
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.hist(np.abs(clust_all[0]), alpha=.5, label='15 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[0]), alpha=.5 , label='15 Clusters, Matrix Clustering', bins=100)
# plt.hist(np.abs(clust_all[-1]), alpha=.5, label='105 Clusters, Latent Clustering, K=2', bins=100)
# plt.hist(np.abs(ref_all[-1]), alpha=.5 , label='105 Clusters, Matrix Clustering', bins=100)
plt.title('Distribution of Differences \n Adult Dataset')
plt.yscale('log', nonposy='clip')
plt.ylabel('Log Number of Occurences')
plt.xlabel('Difference')
plt.legend(loc='best')
# plt.tick_params(axis='both', which='major', labelsize=16)
# plt.tick_params(axis='both', which='minor', labelsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.hist(np.abs(clust_all[-1]), alpha=.5, label='105 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[-1]), alpha=.5 , label='105 Clusters, Matrix Clustering', bins=100)
plt.title('Distribution of Differences \n Adult Dataset',  fontsize=30)
plt.yscale('log', nonposy='clip')
plt.ylabel('Log Number of Occurences',  fontsize=20)
plt.xlabel('Difference',  fontsize=20)
plt.legend(loc='best', prop={'size': 18})
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.hist(np.abs(clust_all[-1]), alpha=.5, label='105 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[-1]), alpha=.5 , label='105 Clusters, Matrix Clustering', bins=100)
plt.title('Distribution of Differences \n Adult Dataset')
plt.yscale('log', nonposy='clip')
plt.ylabel('Log Number of Occurences')
plt.xlabel('Difference')
plt.legend(loc='best')
# plt.tick_params(axis='both', which='major', labelsize=16)
# plt.tick_params(axis='both', which='minor', labelsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.hist(np.abs(clust_all[0]), alpha=.5, label='15 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[0]), alpha=.5 , label='15 Clusters, Matrix Clustering', bins=100)
plt.hist(np.abs(clust_all[-1]), alpha=.5, label='105 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[-1]), alpha=.5 , label='105 Clusters, Matrix Clustering', bins=100)
plt.title('Distribution of Differences \n Adult Dataset',  fontsize=30)
plt.yscale('log', nonposy='clip')
plt.ylabel('Log Number of Occurences',  fontsize=20)
plt.xlabel('Difference',  fontsize=20)
plt.legend(loc='best', prop={'size': 18})
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.show()

# %%
fig = plt.figure(figsize=(10, 7))
plt.hist(np.abs(clust_all[0]), alpha=.5, label='15 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[0]), alpha=.5 , label='15 Clusters, Matrix Clustering', bins=100)
plt.hist(np.abs(clust_all[-1]), alpha=.5, label='105 Clusters, Latent Clustering, K=2', bins=100)
plt.hist(np.abs(ref_all[-1]), alpha=.5 , label='105 Clusters, Matrix Clustering', bins=100)
plt.title('Distribution of Differences \n Adult Dataset')
plt.yscale('log', nonposy='clip')
plt.ylabel('Log Number of Occurences')
plt.xlabel('Difference')
plt.legend(loc='best')
# plt.tick_params(axis='both', which='major', labelsize=16)
# plt.tick_params(axis='both', which='minor', labelsize=16)
plt.show()

# %%
clust_scores = []
clust_all = []
for num_clust in range(15,115,15):
    clust_scores.append(np.loadtxt('./scores/clust_{}_dist_scores_adult.csv'.format(num_clust)))
for num_clust in [15, 75, 105]:
    clust_all.append(np.loadtxt('./scores/dist_all_clust_{}_{}_adult.csv'.format(num_clust, 2)))

# %%
clust_scores = np.array(clust_scores)

# %%
ref_scores_gp = np.loadtxt('./ref/ref_scores.csv')

# %%
clust_scores_gj = []
clust_all_gj = []
for num_clust in range(100,350,50):
    clust_scores_gj.append(np.loadtxt('./scores/clust_{}_dist_scores.csv'.format(num_clust)))

# %%
for num_clust in range(100,350,50):
    print('./scores/clust_{}_dist_scores.csv'.format(num_clust))
# Out:
# ./scores/clust_100_dist_scores.csv
# ./scores/clust_150_dist_scores.csv
# ./scores/clust_200_dist_scores.csv
# ./scores/clust_250_dist_scores.csv
# ./scores/clust_300_dist_scores.csv

# %%
clust_scores_gj = np.array(clust_scores_gj)

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(range(100,350,50), ref_scores_gp[:,0], label='Delta Matrix Clustering')
plt.plot(range(100,350,50), clust_scores_gj[:,0,0], c='r', label = 'Latent Variables, K=2')
plt.plot(range(100,350,50), clust_scores_gj[:,2,0], c='g', label = 'Latent Variables, K=6')
plt.plot(range(100,350,50), clust_scores_gj[:,4,0], c='y', label = 'Latent Variables, K=10')
plt.xlabel('Number of Clusters', fontsize=20)
plt.ylabel('Average Distance Between \n Cluster and Original Matrix', fontsize=20)
plt.legend(loc='center left', prop={'size': 18})
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.title('Comparison of Latent Variable and \n Delta Matrix Clustering, GJ Dataset',  fontsize=30)
plt.show()

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(range(100,350,50), ref_scores_gp[:,0], label='Delta Matrix Clustering')
plt.plot(range(100,350,50), clust_scores_gj[:,0,0], c='r', label = 'Latent Variables, K=2')
plt.plot(range(100,350,50), clust_scores_gj[:,2,0], c='g', label = 'Latent Variables, K=6')
plt.plot(range(100,350,50), clust_scores_gj[:,4,0], c='y', label = 'Latent Variables, K=10')
plt.xlabel('Number of Clusters')
plt.ylabel('Average Distance Between \n Cluster and Original Matrix')
plt.legend(loc='center left')
# plt.tick_params(axis='both', which='major', labelsize=16)
# plt.tick_params(axis='both', which='minor', labelsize=16)
plt.title('Comparison of Latent Variable and \n Delta Matrix Clustering, GJ Dataset')
plt.show()

# %%
l1errors = []
for num_clust in range(100,350,50):
    l1errors.append(np.loadtxt('./scores_old/clust_{}_val_scores.csv'.format(num_clust)))

# %%
l1errors = np.array(l1errors)

# %%
l1errors[0]
# Out:
# array([[  2.        ,   0.22929458,   0.17360905],
#        [  4.        ,   0.24083417,   0.18641958],
#        [  6.        ,   0.26435324,   0.21003935],
#        [  8.        ,   0.27963345,   0.22472395],
#        [ 10.        ,   0.2868754 ,   0.23151665]])

# %%
time_lv = np.loadtxt('./lv_speed.csv')

# %%
time_ref = np.loadtxt('./ref_speed.csv')

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(range(15,115,15), time_ref, label='Matrix Clustering')
plt.plot(range(15,115,15), time_lv[0], label='K=2 Latent Variable')
plt.plot(range(15,115,15), time_lv[2], label='K=6 Latent Variable')
plt.plot(range(15,115,15), time_lv[4], label='K=10 Latent Variable')
plt.legend(loc='best', prop={'size': 18})
plt.xlabel('Number of Clusters', fontsize=20)
plt.ylabel('Clustering Time (s)', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.tick_params(axis='both', which='minor', labelsize=16)
plt.title('Timing of Latent Variable and \n Delta Matrix Clustering, Adult Dataset',  fontsize=30)
plt.show()

# %%
fig = plt.figure(figsize=(8, 5))
plt.plot(range(15,115,15), time_ref, label='Matrix Clustering')
plt.plot(range(15,115,15), time_lv[0], label='K=2 Latent Variable')
plt.plot(range(15,115,15), time_lv[2], label='K=6 Latent Variable')
plt.plot(range(15,115,15), time_lv[4], label='K=10 Latent Variable')
plt.legend(loc='best')
plt.xlabel('Number of Clusters')
plt.ylabel('Clustering Time (s)')
# plt.tick_params(axis='both', which='major', labelsize=16)
# plt.tick_params(axis='both', which='minor', labelsize=16)
plt.title('Timing of Latent Variable and \n Delta Matrix Clustering, Adult Dataset')
plt.show()
